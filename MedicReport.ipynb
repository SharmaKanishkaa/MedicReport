# %% [markdown]
# <a href="https://colab.research.google.com/github/SharmaKanishkaa/MedicReport/blob/main/MedicReport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install streamlit
# !pip install pdf2image PyPDF2 pytesseract pillow
# !pip install transformers torch
# !apt-get install -y poppler-utils tesseract-ocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 23.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 11.9 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   poppler-utils tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 4 newly installed, 0 to remove and 49 not upgraded.
# Need to get 5,002 kB of archives.
# ...

# %%
# Change to the directory where your file is located
# %cd /content/drive/MyDrive/MedicReport
# Out:
# /content/drive/MyDrive/MedicReport

# %%
# !python MedicReportapp.py
# Out:
# 2024-10-16 19:11:13.697211: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-16 19:11:13.720954: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-16 19:11:13.728151: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-16 19:11:13.745788: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# Read the contents of the file
with open('MedicReportapp.py', 'r') as file:
    code = file.read()

# Display the code
print(code)
# Out:
# %writefile /content/drive/MyDrive/MedicReportapp.py
# # Include the complete code you provided earlier
# import streamlit as st
# import os
# import pandas as pd
# from pdf2image import convert_from_path
# from PIL import Image
# import PyPDF2
# import pytesseract
# from transformers import AutoTokenizer, AutoModelForTokenClassification, AutoModelForSeq2SeqLM, AutoModelForSequenceClassification, pipeline
# import torch
# # Function to extract text from a text-based PDF
# def extract_text_pdf(file_path):
#     reader = PyPDF2.PdfReader(file_path)
#     text = ""
#     for page in range(len(reader.pages)):
#         text += reader.pages[page].extract_text()
#     return text
# # Function to extract text from an image-based PDF using OCR
# def extract_text_image_pdf(file_path):
#     images = convert_from_path(file_path)
#     text = ""
#     for image in images:
#         text += pytesseract.image_to_string(image)
#     return text
# # Function to extract text from JPG/PNG images
# ...
